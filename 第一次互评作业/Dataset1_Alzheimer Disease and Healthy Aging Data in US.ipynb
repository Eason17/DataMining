# %% [markdown]
# # Dataset 1: Alzheimer Disease and Healthy Aging Data in US

# %%
import pandas as pd

# %% [markdown]
# ### 读取csv文件

# %%
path = r'D:\BIT\研一下\数据挖掘\作业\数据分析\Alzheimer Disease and Healthy Aging Data In US.csv'
df = pd.read_csv(path)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14000\364044176.py:2: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %% [markdown]
# ### 任务1：进行数据摘要和可视化
# 首先我们需要分析读取进来的数据表都具有哪些数据属性，为后续数据摘要做准备。

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'DataValueTypeID',
#        'Data_Value_Type', 'Data_Value', 'Data_Value_Alt',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'Sample_Size',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'Geolocation', 'ClassID', 'TopicID', 'QuestionID',
#        'LocationID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2'],
#       dtype='object')

# %% [markdown]
# #### 简要分析
# 该数据集描述的是阿尔茨海默症和健康老龄化数据提供有关美国老年人健康和福祉的信息，重点关注阿尔茨海默症和相关痴呆症。从上述结果中不难发现，数据集包含以下标签，在此我对这些标签进行了一个简要的解释：
# <br>
# * YearStart：数据收集开始的年份；
# * YearEnd：数据收集结束的年份；
# * LocationAbbr：收集数据的位置的缩写；
# * LocationDesc：收集数据的位置的全名；
# * Datasource：数据的来源；
# * Class：数据的类别；
# * Topic：数据的主题；
# * Question：与数据相关的问题；
# * Data_Value_Unit：数据值的度量单位；
# * DataValueTypeID：数据值类型的 ID；
# * Data_Value_Type：数据值的类型（例如平均值、百分比）；
# * Data_Value：实际数据值；
# * Data_Value_Alt：替代数据值（如果适用）；
# * Low_Confidence_Limit：数据值置信区间的下限；
# * High_Confidence_Limit：数据值置信区间的上限；
# * Sample_Size：用于收集数据的样本大小；
# * StratificationCategory1：用于分层的第一个类别（例如年龄组）；
# * Stratification1：使用的具体分层（例如 18-24 岁）；
# * StratificationCategory2：用于分层的第二个类别（如果适用）；
# * Stratification2：用于第二类的特定分层（如果适用）；
# * Geolocation：收集数据的位置的纬度和经度；
# * ClassID：数据类的 ID；
# * TopicID：数据主题的 ID；
# * QuestionID：与数据相关的问题的 ID；
# * LocationID：收集数据的位置的 ID；
# * StratificationCategoryID1：用于分层的第一个类别的 ID；
# * StratificationID1：用于第一个类别的特定分层的 ID；
# * StratificationCategoryID2：用于分层的第二个类别的 ID；
# * StratificationID2：用于第二个类别的特定分层的 ID。

# %% [markdown]
# 我们需要对以上数据属性进行分类。众所周知，标称属性代表了某一种类别、编码或状态，标称属性的值不具有有意义的一个顺序，是一种离散的变量，其取值是有限且相互独立的，没有任何内在的排序或数量关系；数值属性则是一种可以度量的量，即我们可以使用实数值对这些量进行表示，同样也可以使用标度来进行衡量。
# <br><br>
#
# 因此，为了区分数据表中的标称属性和数值属性，我们需要对该数据表中的数据类型进行描述。于是，我将进行以下操作：

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214462 entries, 0 to 214461
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   YearStart                  214462 non-null  int64
#  1   YearEnd                    214462 non-null  int64
#  2   LocationAbbr               214462 non-null  object
#  3   LocationDesc               214462 non-null  object
#  4   Datasource                 214462 non-null  object
#  5   Class                      214462 non-null  object
#  6   Topic                      214462 non-null  object
#  7   Question                   214462 non-null  object
#  8   Data_Value_Unit            214462 non-null  object
#  9   DataValueTypeID            214462 non-null  object
#  10  Data_Value_Type            214462 non-null  object
#  11  Data_Value                 144629 non-null  float64
#  12  Data_Value_Alt             144629 non-null  float64
# ...

# %% [markdown]
# 上述操作对数据表中的数据属性的类别进行了分类，我们不难发现有6个数值属性（3 float64 + 3 int64），我们可以将object类型理解为标称属性，因此该数据表中具有23个标称属性。我们将该数据表中的object类型的列截取出来，进行频数统计。紧接着，在对数值类型的列进行五数统计。

# %%
object_columns = df.select_dtypes(include='object').columns

# 计算标称属性的频数
frequecy_list = [df[index].value_counts() for index in object_columns]
[print(frequecy) for frequecy in frequecy_list]
# Out:
# US      4644
# WEST    4638
# NRE     4614
# MDW     4611
# OR      4565
# NY      4557
# SOU     4542
# UT      4222
# OH      3955
# GA      3951
# MD      3919
# HI      3907
# TN      3879
# MI      3796
# VA      3758
# FL      3753
# ME      3733
# TX      3699
# NV      3696
# DC      3684
# WV      3682
# MS      3677
# PA      3648
# NM      3635
# AL      3633
# KY      3623
# AK      3611
# SC      3592
# NJ      3589
# AZ      3582
# MO      3573
# IL      3571
# IN      3570
# WI      3569
# LA      3563
# MN      3555
# NE      3546
# CT      3543
# RI      3534
# OK      3526
# SD      3526
# ND      3514
# KS      3510
# ID      3507
# IA      3501
# AR      3498
# WY      3494
# CA      3447
# CO      3390
# NC      3349
# WA      3348
# MT      3348
# DE      3346
# NH      3284
# VT      3278
# MA      3174
# PR      2797
# GU      2703
# VI       503
# Name: LocationAbbr, dtype: int64
# United States, DC & Territories    4644
# ...

# %%
# 数值属性的五数统计
df.describe().loc[['min', '25%', '50%', '75%', 'max'], :]
# Out:
#      YearStart  YearEnd  Data_Value  Data_Value_Alt  Sample_Size  LocationID
# min     2015.0   2015.0         0.0             0.0          NaN         1.0
# 25%     2016.0   2016.0        15.3            15.3          NaN        18.0
# 50%     2017.0   2018.0        32.5            32.5          NaN        33.0
# 75%     2019.0   2019.0        56.8            56.8          NaN        49.0
# max     2020.0   2020.0       100.0           100.0          NaN      9004.0

# %%
# 计算缺失值的个数
missing_values_count = df.isna().sum()
missing_values_count
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit                   0
# DataValueTypeID                   0
# Data_Value_Type                   0
# Data_Value                    69833
# Data_Value_Alt                69833
# Low_Confidence_Limit          69990
# High_Confidence_Limit         69990
# Sample_Size                  214462
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2       27669
# Stratification2               27669
# Geolocation                   23049
# ClassID                           0
# TopicID                           0
# QuestionID                        0
# LocationID                        0
# StratificationCategoryID1         0
# ...

# %% [markdown]
# 在完成对于数据摘要后，需要进行数据的可视化，我将绘制直方图与盒图，来检查数据的分布以及数据中的离群点。

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 同样地，我们将数据表中的数据分为标称属性和数值属性进行可视化，其中标称属性使用频数分布图进行可视化，数值属性使用真实数据的统计分布，相关可视化的图如下：

# %%
for column in object_columns:
    df[f'{column}'].value_counts().plot(kind="bar", title=f"{column}")
    plt.show()

# %%
num_columns = df.select_dtypes(include=['int64', 'float64']).columns
for column in num_columns:
    df[f'{column}'].plot(kind="hist", title=f"{column}")
    plt.show()

# %%
for column in num_columns:
    df[f'{column}'].plot(kind="box", title=f"{column}")
    plt.show()

# %% [markdown]
# 从上述绘制的数据直方图和盒图中不难看出，YearStart和YearEnd两个数据属性不存在有对应的离群值，即对于“起始年份--终止年份”数据对象，不存在异常的离群值。对于Data_Value和Data_Value_Alt两种数据属性，其数据分布具有相似性，我们有理由认为这两组数据属性表示的是同一种数据内容。而Sample_Size这一数据属性可视化的结果为空，说明该组数据为全空，我们需要手动剔除。对于LocationID，能明显从可视化结果中看出，其中存在一个明显的离群点。

# %% [markdown]
# ### 任务2：数据缺失的处理

# %% [markdown]
# 在先前可视化中可以发现，‘Sample_Size’列不存在数据，因此我们将这一列整体从数据表中移除。

# %%
df = df.drop('Sample_Size', axis=1)

# %% [markdown]
# 在处理缺失数据之前，我们首先需要知道DataFrame中一共有多少行或列存在缺失值，使用以下代码进行读取：

# %%
na_columns = df.loc[:, (df.isnull().any())].columns
na_columns
# Out:
# Index(['Data_Value', 'Data_Value_Alt', 'Low_Confidence_Limit',
#        'High_Confidence_Limit', 'StratificationCategory2', 'Stratification2',
#        'Geolocation'],
#       dtype='object')

# %% [markdown]
# 由此，我们不难发现，在DataFrame中一共有七个数据属性存在有缺失值。对于不同属性（标称属性和数值属性）缺失值的处理方式是不尽相同的，因此我首先对存在缺失值的这七个属性中包含数据对象的数据类型进行分类，并在后续操作中采取不同的方式对不同数据类型的缺失值进行修补。
# <br><br>
#
# 按照要求，我将分别使用四种策略对缺失值进行处理：
# 1. 将缺失部分剔除：我将使用dropna()方法将DataFrame中含有缺失值的行或列删除。

# %%
df_dropna_1 = df.copy()
df_dropna_1 = df_dropna_1.dropna()
df_dropna_1
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc Datasource  \
# 4            2020     2020           IN      Indiana      BRFSS
# 8            2019     2019           IA         Iowa      BRFSS
# 11           2019     2019           KS       Kansas      BRFSS
# 15           2017     2017           KY     Kentucky      BRFSS
# 18           2020     2020           ME        Maine      BRFSS
# ...           ...      ...          ...          ...        ...
# 214447       2019     2019           WY      Wyoming      BRFSS
# 214448       2016     2016           WY      Wyoming      BRFSS
# 214449       2019     2019           WY      Wyoming      BRFSS
# 214452       2016     2016           WY      Wyoming      BRFSS
# 214454       2015     2015           WY      Wyoming      BRFSS
#
#                                       Class  \
# 4                             Mental Health
# 8                            Overall Health
# 11                            Mental Health
# ...

# %% [markdown]
# 2. 用最高频率值来填补缺失值：在此我使用fillna()方法将缺失值替换为最高频率值。

# %%
df_dropna_2 = df.copy()
most_frequent_value = [df_dropna_2[f'{column}'].value_counts().idxmax() for column in na_columns]
[df_dropna_2[f'{column}'].fillna(value, inplace=True) for column, value in zip(na_columns, most_frequent_value)]
df_dropna_2
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc Datasource  \
# 0            2020     2020           HI       Hawaii      BRFSS
# 1            2017     2017           ID        Idaho      BRFSS
# 2            2017     2017           ID        Idaho      BRFSS
# 3            2018     2018           ID        Idaho      BRFSS
# 4            2020     2020           IN      Indiana      BRFSS
# ...           ...      ...          ...          ...        ...
# 214457       2016     2016           WY      Wyoming      BRFSS
# 214458       2015     2015           WY      Wyoming      BRFSS
# 214459       2017     2017           WY      Wyoming      BRFSS
# 214460       2016     2016           WY      Wyoming      BRFSS
# 214461       2018     2018           WY      Wyoming      BRFSS
#
#                           Class  \
# 0                Overall Health
# 1                 Mental Health
# 2                Overall Health
# 3                Overall Health
# ...

# %% [markdown]
# 3. 通过属性的相关关系来填补缺失值：使用corr()来计算数据表中各列之间的相关系数，选择相关性最高的列，使用相关性系数乘积的线性加合，来填充缺失值。

# %%
# 对于object类型，我处理的方式是进行类型转换
df_dropna_3 = df.copy()
df_dropna_3['Low_Confidence_Limit'] = pd.to_numeric(df_dropna_3['Low_Confidence_Limit'], errors='coerce')
df_dropna_3['High_Confidence_Limit'] = pd.to_numeric(df_dropna_3['High_Confidence_Limit'], errors='coerce')

# %%
# 我们通过计算相关性矩阵，来判断各列（数值类型）之间的相关关系
corr_matrix = df_dropna_3.corr()
corr_matrix
# Out:
#                        YearStart   YearEnd  Data_Value  Data_Value_Alt  \
# YearStart               1.000000  0.808550    0.040190        0.040190
# YearEnd                 0.808550  1.000000    0.010573        0.010573
# Data_Value              0.040190  0.010573    1.000000        1.000000
# Data_Value_Alt          0.040190  0.010573    1.000000        1.000000
# Low_Confidence_Limit    0.043679  0.002832    0.983967        0.983967
# High_Confidence_Limit   0.035203  0.018413    0.983857        0.983857
# LocationID              0.006805  0.003154   -0.012051       -0.012051
#
#                        Low_Confidence_Limit  High_Confidence_Limit  LocationID
# YearStart                          0.043679               0.035203    0.006805
# YearEnd                            0.002832               0.018413    0.003154
# Data_Value                         0.983967               0.983857   -0.012051
# Data_Value_Alt                     0.983967               0.983857   -0.012051
# ...

# %%
# 选择出与缺失列相关性最高列，并存储对应的相关系数(index 0是自身，index 1是相关性最高的其他列)
for column in na_columns[:4]:
    highest_corr = corr_matrix[column].sort_values(ascending=False).index[1]
    df_dropna_3[column].fillna(df_dropna_3[highest_corr].mean(), inplace=True)
df_dropna_3
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc Datasource  \
# 0            2020     2020           HI       Hawaii      BRFSS
# 1            2017     2017           ID        Idaho      BRFSS
# 2            2017     2017           ID        Idaho      BRFSS
# 3            2018     2018           ID        Idaho      BRFSS
# 4            2020     2020           IN      Indiana      BRFSS
# ...           ...      ...          ...          ...        ...
# 214457       2016     2016           WY      Wyoming      BRFSS
# 214458       2015     2015           WY      Wyoming      BRFSS
# 214459       2017     2017           WY      Wyoming      BRFSS
# 214460       2016     2016           WY      Wyoming      BRFSS
# 214461       2018     2018           WY      Wyoming      BRFSS
#
#                           Class  \
# 0                Overall Health
# 1                 Mental Health
# 2                Overall Health
# 3                Overall Health
# ...

# %% [markdown]
# 4. 通过数据对象之间的相似性来填补缺失值：<br><br>
# 首先我们需要分析数据对象之间的相似性，显而易见地是，缺失值所在列的其他未缺失值与这些缺失值的相似性最高。因此，一个合适的方法就是使用同一列中其他未缺失的数据对象的值来代表。对于数值属性，我们就使用均值来填充缺失值；对于标称属性，我们就使用众数来填充缺失值。

# %%
# 同样地，我们对object类型进行数值转换
df_dropna_4 = df.copy()
df_dropna_4['Low_Confidence_Limit'] = pd.to_numeric(df_dropna_4['Low_Confidence_Limit'], errors='coerce')
df_dropna_4['High_Confidence_Limit'] = pd.to_numeric(df_dropna_4['High_Confidence_Limit'], errors='coerce')

# %%
for column in na_columns[:4]:
    df_dropna_4[column].fillna(df_dropna_4[column].mean(), inplace=True)

for column in na_columns[4:]:
    df_dropna_4[column].fillna(df_dropna_4[column].mode().iloc[0], inplace=True)

# %% [markdown]
# ### 任务3：比较处理缺失值后数据集的差异

# %% [markdown]
# 在此，我尝试使用数据摘要的方式对新旧数据集进行一个比较。我将对这四个数据集中的数据进行汇总统计，如计算两个数据集中的均值、中位数、方差、标准差等统计量，最后比较它们之间的差异。

# %%
df.describe()
# Out:
#            YearStart        YearEnd     Data_Value  Data_Value_Alt  \
# count  214462.000000  214462.000000  144629.000000   144629.000000
# mean     2017.378477    2017.634000      37.341956       37.341956
# std         1.779822       1.778926      25.183017       25.183017
# min      2015.000000    2015.000000       0.000000        0.000000
# 25%      2016.000000    2016.000000      15.300000       15.300000
# 50%      2017.000000    2018.000000      32.500000       32.500000
# 75%      2019.000000    2019.000000      56.800000       56.800000
# max      2020.000000    2020.000000     100.000000      100.000000
#
#           LocationID
# count  214462.000000
# mean      800.987821
# std      2512.934094
# min         1.000000
# 25%        18.000000
# 50%        33.000000
# 75%        49.000000
# max      9004.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214462 entries, 0 to 214461
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   YearStart                  214462 non-null  int64
#  1   YearEnd                    214462 non-null  int64
#  2   LocationAbbr               214462 non-null  object
#  3   LocationDesc               214462 non-null  object
#  4   Datasource                 214462 non-null  object
#  5   Class                      214462 non-null  object
#  6   Topic                      214462 non-null  object
#  7   Question                   214462 non-null  object
#  8   Data_Value_Unit            214462 non-null  object
#  9   DataValueTypeID            214462 non-null  object
#  10  Data_Value_Type            214462 non-null  object
#  11  Data_Value                 144629 non-null  float64
#  12  Data_Value_Alt             144629 non-null  float64
# ...

# %%
missing_values_count_df = df.isna().sum()
missing_values_count_df
# Out:
# YearStart                        0
# YearEnd                          0
# LocationAbbr                     0
# LocationDesc                     0
# Datasource                       0
# Class                            0
# Topic                            0
# Question                         0
# Data_Value_Unit                  0
# DataValueTypeID                  0
# Data_Value_Type                  0
# Data_Value                   69833
# Data_Value_Alt               69833
# Low_Confidence_Limit         69990
# High_Confidence_Limit        69990
# StratificationCategory1          0
# Stratification1                  0
# StratificationCategory2      27669
# Stratification2              27669
# Geolocation                  23049
# ClassID                          0
# TopicID                          0
# QuestionID                       0
# LocationID                       0
# StratificationCategoryID1        0
# StratificationID1                0
# StratificationCategoryID2        0
# ...

# %%
missing_values_count_1 = df_dropna_1.isna().sum()
missing_values_count_1
# Out:
# YearStart                    0
# YearEnd                      0
# LocationAbbr                 0
# LocationDesc                 0
# Datasource                   0
# Class                        0
# Topic                        0
# Question                     0
# Data_Value_Unit              0
# DataValueTypeID              0
# Data_Value_Type              0
# Data_Value                   0
# Data_Value_Alt               0
# Low_Confidence_Limit         0
# High_Confidence_Limit        0
# StratificationCategory1      0
# Stratification1              0
# StratificationCategory2      0
# Stratification2              0
# Geolocation                  0
# ClassID                      0
# TopicID                      0
# QuestionID                   0
# LocationID                   0
# StratificationCategoryID1    0
# StratificationID1            0
# StratificationCategoryID2    0
# StratificationID2            0
# dtype: int64

# %%
df_dropna_1.describe()
# Out:
#           YearStart       YearEnd    Data_Value  Data_Value_Alt    LocationID
# count  97238.000000  97238.000000  97238.000000    97238.000000  97238.000000
# mean    2017.393766   2017.604743     37.663025       37.663025     29.681966
# std        1.765871      1.765960     25.306987       25.306987     16.776706
# min     2015.000000   2015.000000      1.000000        1.000000      1.000000
# 25%     2016.000000   2016.000000     15.500000       15.500000     16.000000
# 50%     2017.000000   2018.000000     32.900000       32.900000     29.000000
# 75%     2019.000000   2019.000000     57.400000       57.400000     42.000000
# max     2020.000000   2020.000000     99.900000       99.900000     78.000000

# %%
missing_values_count_2 = df_dropna_2.isna().sum()
missing_values_count_2
# Out:
# YearStart                    0
# YearEnd                      0
# LocationAbbr                 0
# LocationDesc                 0
# Datasource                   0
# Class                        0
# Topic                        0
# Question                     0
# Data_Value_Unit              0
# DataValueTypeID              0
# Data_Value_Type              0
# Data_Value                   0
# Data_Value_Alt               0
# Low_Confidence_Limit         0
# High_Confidence_Limit        0
# StratificationCategory1      0
# Stratification1              0
# StratificationCategory2      0
# Stratification2              0
# Geolocation                  0
# ClassID                      0
# TopicID                      0
# QuestionID                   0
# LocationID                   0
# StratificationCategoryID1    0
# StratificationID1            0
# StratificationCategoryID2    0
# StratificationID2            0
# dtype: int64

# %%
df_dropna_2.describe()
# Out:
#            YearStart        YearEnd     Data_Value  Data_Value_Alt  \
# count  214462.000000  214462.000000  214462.000000   214462.000000
# mean     2017.378477    2017.634000      27.136405       27.136405
# std         1.779822       1.778926      25.365139       25.365139
# min      2015.000000    2015.000000       0.000000        0.000000
# 25%      2016.000000    2016.000000       6.000000        6.000000
# 50%      2017.000000    2018.000000      15.900000       15.900000
# 75%      2019.000000    2019.000000      42.100000       42.100000
# max      2020.000000    2020.000000     100.000000      100.000000
#
#           LocationID
# count  214462.000000
# mean      800.987821
# std      2512.934094
# min         1.000000
# 25%        18.000000
# 50%        33.000000
# 75%        49.000000
# max      9004.000000

# %%
missing_values_count_3 = df_dropna_3.isna().sum()
missing_values_count_3
# Out:
# YearStart                        0
# YearEnd                          0
# LocationAbbr                     0
# LocationDesc                     0
# Datasource                       0
# Class                            0
# Topic                            0
# Question                         0
# Data_Value_Unit                  0
# DataValueTypeID                  0
# Data_Value_Type                  0
# Data_Value                       0
# Data_Value_Alt                   0
# Low_Confidence_Limit             0
# High_Confidence_Limit            0
# StratificationCategory1          0
# Stratification1                  0
# StratificationCategory2      27669
# Stratification2              27669
# Geolocation                  23049
# ClassID                          0
# TopicID                          0
# QuestionID                       0
# LocationID                       0
# StratificationCategoryID1        0
# StratificationID1                0
# StratificationCategoryID2        0
# ...

# %%
df_dropna_3.describe()
# Out:
#            YearStart        YearEnd     Data_Value  Data_Value_Alt  \
# count  214462.000000  214462.000000  214462.000000   214462.000000
# mean     2017.378477    2017.634000      37.341956       37.341956
# std         1.779822       1.778926      20.680441       20.680441
# min      2015.000000    2015.000000       0.000000        0.000000
# 25%      2016.000000    2016.000000      23.800000       23.800000
# 50%      2017.000000    2018.000000      37.341956       37.341956
# 75%      2019.000000    2019.000000      42.100000       42.100000
# max      2020.000000    2020.000000     100.000000      100.000000
#
#        Low_Confidence_Limit  High_Confidence_Limit     LocationID
# count         214462.000000          214462.000000  214462.000000
# mean              34.240097              40.644070     800.987821
# std               20.004054              21.602473    2512.934094
# min                0.000000               1.400000       1.000000
# ...

# %%
missing_values_count_4 = df_dropna_4.isna().sum()
missing_values_count_4
# Out:
# YearStart                    0
# YearEnd                      0
# LocationAbbr                 0
# LocationDesc                 0
# Datasource                   0
# Class                        0
# Topic                        0
# Question                     0
# Data_Value_Unit              0
# DataValueTypeID              0
# Data_Value_Type              0
# Data_Value                   0
# Data_Value_Alt               0
# Low_Confidence_Limit         0
# High_Confidence_Limit        0
# StratificationCategory1      0
# Stratification1              0
# StratificationCategory2      0
# Stratification2              0
# Geolocation                  0
# ClassID                      0
# TopicID                      0
# QuestionID                   0
# LocationID                   0
# StratificationCategoryID1    0
# StratificationID1            0
# StratificationCategoryID2    0
# StratificationID2            0
# dtype: int64

# %%
df_dropna_4.describe()
# Out:
#            YearStart        YearEnd     Data_Value  Data_Value_Alt  \
# count  214462.000000  214462.000000  214462.000000   214462.000000
# mean     2017.378477    2017.634000      37.341956       37.341956
# std         1.779822       1.778926      20.680441       20.680441
# min      2015.000000    2015.000000       0.000000        0.000000
# 25%      2016.000000    2016.000000      23.800000       23.800000
# 50%      2017.000000    2018.000000      37.341956       37.341956
# 75%      2019.000000    2019.000000      42.100000       42.100000
# max      2020.000000    2020.000000     100.000000      100.000000
#
#        Low_Confidence_Limit  High_Confidence_Limit     LocationID
# count         214462.000000          214462.000000  214462.000000
# mean              32.736785              42.244436     800.987821
# std               19.887159              21.479810    2512.934094
# min                0.000000               1.400000       1.000000
# ...
